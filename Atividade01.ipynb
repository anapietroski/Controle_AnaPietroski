# %%
# Utilizando Pandas para abrir a planilha
import pandas as pd
import os

# Coletando o caminho da pasta de que estou
cwd = os.getcwd()
print(cwd)

# Pasta dos fatores de emissão
path = cwd+'\\tabelas\\FE'
print(path)

# Indicando nome do arquivo
chapterNumer = 10
subChapter = 2
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'
print(file)

# Abrindo arquivo utilizando o Pandas
fe = pd.read_csv(path + '\\'+file)
print(fe)
# Out:
# C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski
# C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski\tabelas\FE
# chp_10_2.csv
#                           Source    MP    SO2    CO
# 0  Tanque de dissolucao do smelt   3.5  0.100   NaN
# 1                   Forno de cal  28.0  0.150  0.05
# 2      Condensador de terebitina   NaN    NaN   NaN
# 3   Caldeira de forca (biomassa)   3.6  0.225  5.40

# %%
#Estimativa das emissões do empreendimento (e plotagem)

import matplotlib.pyplot as plt

atv = 70000 #Considerando taxa de atividade em toneladas/ano
emis = fe['MP']*atv

#Somando dataframe
print(emis.sum())

#Criando a figura com Matplotlib
#Subplots com número de linhas igual ao numero de poluentes
fig, ax = plt.subplots(len(fe.columns) - 1, 1, sharex = True, figsize=(9, 15)) #sharex significa compartilhar o eixo x

#Look para preencher o subplot com os gráficos de barra
for ii in range(1, len(fe.columns)): #a primeira coluna é a identificação da fonte
    ax[ii-1].bar(fe['Source'], fe.iloc[:,ii], color = 'black')
    ax[ii-1].set_xlabel('Processo', fontsize=8) #coloca o eixo x
    ax[ii-1].set_ylabel(fe.columns[ii]+'\n(kg/ton)', fontsize=8)

    ax[ii-1].tick_params(axis='x', labelsize=8)
    ax[ii-1].tick_params(axis='y', labelsize=8)

    ax[ii-1].set_xticks(fe['Source'].index)
    ax[ii-1].set_xticklabels(fe['Source'], rotation=45, ha='right', fontsize=8)

# Adicionando valores acima das barras
    for bar, value in zip(ax[ii - 1].patches, fe.iloc[:, ii]):
        ax[ii - 1].annotate('{:.2f}'.format(value), xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
                            xytext=(0, 3),  # 3 points vertical offset
                            textcoords="offset points",
                            ha='center', va='bottom', fontsize=8)

#O gráfico a seguir representa o fator de emissão para cada processo, basicamente pegou os dados da tabela e apresentou em figura
# Out:
# 2457000.0

# %%
df = pd.read_csv(path + '\\'+file)

# Encontrando a emissão dos poluentes para cada processo 
poluentes = ['MP', 'SO2', 'CO']
df[poluentes] *= atv

print(df)
# Out:
#                           Source         MP      SO2        CO
# 0  Tanque de dissolucao do smelt   245000.0   7000.0       NaN
# 1                   Forno de cal  1960000.0  10500.0    3500.0
# 2      Condensador de terebitina        NaN      NaN       NaN
# 3   Caldeira de forca (biomassa)   252000.0  15750.0  378000.0

# %%
# Criando vetor de valores aleatórios. Será criado em ton/dia para melhor cálculo das etapas seguintes.
import numpy as np
atvMax = 0.00225 #atividade máxima de produção em ton/dia
atvMin = 0.00150 #atividade mínima diária de produção em ton/dia
n = 1000 #1000 valores aleatórios
atv = (atvMax - atvMin)*np.random.rand(n) + atvMin

#Criando uma figura com os valores aleatórios
fig, ax = plt.subplots()

plt.xlabel('Valores aleatórios')
plt.ylabel('Atividade (ton/s)')
    
ax.plot(atv, color = 'black')

# %%
# Criar um vetor com as datas para o ano de 2024

from datetime import datetime, timedelta

# Definindo a data inicial e final
data_inicial = datetime(2024, 1, 1)
data_final = datetime(2024, 12, 31)

# Definindo o passo (intervalo entre as datas)
passo = timedelta(days=1)

# Criando o vetor de datas
vetor_datas = []
data_atual = data_inicial
while data_atual <= data_final:
    vetor_datas.append(data_atual)
    data_atual += passo

# Exibindo o vetor de datas
for data in vetor_datas:
    print(data)
# Out:
# 2024-01-01 00:00:00
# 2024-01-02 00:00:00
# 2024-01-03 00:00:00
# 2024-01-04 00:00:00
# 2024-01-05 00:00:00
# 2024-01-06 00:00:00
# 2024-01-07 00:00:00
# 2024-01-08 00:00:00
# 2024-01-09 00:00:00
# 2024-01-10 00:00:00
# 2024-01-11 00:00:00
# 2024-01-12 00:00:00
# 2024-01-13 00:00:00
# 2024-01-14 00:00:00
# 2024-01-15 00:00:00
# 2024-01-16 00:00:00
# 2024-01-17 00:00:00
# 2024-01-18 00:00:00
# 2024-01-19 00:00:00
# 2024-01-20 00:00:00
# 2024-01-21 00:00:00
# 2024-01-22 00:00:00
# 2024-01-23 00:00:00
# 2024-01-24 00:00:00
# 2024-01-25 00:00:00
# 2024-01-26 00:00:00
# 2024-01-27 00:00:00
# 2024-01-28 00:00:00
# 2024-01-29 00:00:00
# 2024-01-30 00:00:00
# 2024-01-31 00:00:00
# 2024-02-01 00:00:00
# 2024-02-02 00:00:00
# 2024-02-03 00:00:00
# 2024-02-04 00:00:00
# 2024-02-05 00:00:00
# 2024-02-06 00:00:00
# 2024-02-07 00:00:00
# 2024-02-08 00:00:00
# 2024-02-09 00:00:00
# 2024-02-10 00:00:00
# 2024-02-11 00:00:00
# 2024-02-12 00:00:00
# 2024-02-13 00:00:00
# 2024-02-14 00:00:00
# 2024-02-15 00:00:00
# 2024-02-16 00:00:00
# 2024-02-17 00:00:00
# 2024-02-18 00:00:00
# 2024-02-19 00:00:00
# 2024-02-20 00:00:00
# 2024-02-21 00:00:00
# 2024-02-22 00:00:00
# 2024-02-23 00:00:00
# 2024-02-24 00:00:00
# 2024-02-25 00:00:00
# 2024-02-26 00:00:00
# 2024-02-27 00:00:00
# 2024-02-28 00:00:00
# 2024-02-29 00:00:00
# 2024-03-01 00:00:00
# 2024-03-02 00:00:00
# 2024-03-03 00:00:00
# 2024-03-04 00:00:00
# 2024-03-05 00:00:00
# 2024-03-06 00:00:00
# 2024-03-07 00:00:00
# 2024-03-08 00:00:00
# 2024-03-09 00:00:00
# 2024-03-10 00:00:00
# 2024-03-11 00:00:00
# 2024-03-12 00:00:00
# 2024-03-13 00:00:00
# 2024-03-14 00:00:00
# 2024-03-15 00:00:00
# 2024-03-16 00:00:00
# 2024-03-17 00:00:00
# 2024-03-18 00:00:00
# 2024-03-19 00:00:00
# 2024-03-20 00:00:00
# 2024-03-21 00:00:00
# 2024-03-22 00:00:00
# 2024-03-23 00:00:00
# 2024-03-24 00:00:00
# 2024-03-25 00:00:00
# 2024-03-26 00:00:00
# 2024-03-27 00:00:00
# 2024-03-28 00:00:00
# 2024-03-29 00:00:00
# 2024-03-30 00:00:00
# 2024-03-31 00:00:00
# 2024-04-01 00:00:00
# 2024-04-02 00:00:00
# 2024-04-03 00:00:00
# 2024-04-04 00:00:00
# 2024-04-05 00:00:00
# 2024-04-06 00:00:00
# 2024-04-07 00:00:00
# 2024-04-08 00:00:00
# 2024-04-09 00:00:00
# 2024-04-10 00:00:00
# 2024-04-11 00:00:00
# 2024-04-12 00:00:00
# 2024-04-13 00:00:00
# 2024-04-14 00:00:00
# 2024-04-15 00:00:00
# 2024-04-16 00:00:00
# 2024-04-17 00:00:00
# 2024-04-18 00:00:00
# 2024-04-19 00:00:00
# 2024-04-20 00:00:00
# 2024-04-21 00:00:00
# 2024-04-22 00:00:00
# 2024-04-23 00:00:00
# 2024-04-24 00:00:00
# 2024-04-25 00:00:00
# 2024-04-26 00:00:00
# 2024-04-27 00:00:00
# 2024-04-28 00:00:00
# 2024-04-29 00:00:00
# 2024-04-30 00:00:00
# 2024-05-01 00:00:00
# 2024-05-02 00:00:00
# 2024-05-03 00:00:00
# 2024-05-04 00:00:00
# 2024-05-05 00:00:00
# 2024-05-06 00:00:00
# 2024-05-07 00:00:00
# 2024-05-08 00:00:00
# 2024-05-09 00:00:00
# 2024-05-10 00:00:00
# 2024-05-11 00:00:00
# 2024-05-12 00:00:00
# 2024-05-13 00:00:00
# 2024-05-14 00:00:00
# 2024-05-15 00:00:00
# 2024-05-16 00:00:00
# 2024-05-17 00:00:00
# 2024-05-18 00:00:00
# 2024-05-19 00:00:00
# 2024-05-20 00:00:00
# 2024-05-21 00:00:00
# 2024-05-22 00:00:00
# 2024-05-23 00:00:00
# 2024-05-24 00:00:00
# 2024-05-25 00:00:00
# 2024-05-26 00:00:00
# 2024-05-27 00:00:00
# 2024-05-28 00:00:00
# 2024-05-29 00:00:00
# 2024-05-30 00:00:00
# 2024-05-31 00:00:00
# 2024-06-01 00:00:00
# 2024-06-02 00:00:00
# 2024-06-03 00:00:00
# 2024-06-04 00:00:00
# 2024-06-05 00:00:00
# 2024-06-06 00:00:00
# 2024-06-07 00:00:00
# 2024-06-08 00:00:00
# 2024-06-09 00:00:00
# 2024-06-10 00:00:00
# 2024-06-11 00:00:00
# 2024-06-12 00:00:00
# 2024-06-13 00:00:00
# 2024-06-14 00:00:00
# 2024-06-15 00:00:00
# 2024-06-16 00:00:00
# 2024-06-17 00:00:00
# 2024-06-18 00:00:00
# 2024-06-19 00:00:00
# 2024-06-20 00:00:00
# 2024-06-21 00:00:00
# 2024-06-22 00:00:00
# 2024-06-23 00:00:00
# 2024-06-24 00:00:00
# 2024-06-25 00:00:00
# 2024-06-26 00:00:00
# 2024-06-27 00:00:00
# 2024-06-28 00:00:00
# 2024-06-29 00:00:00
# 2024-06-30 00:00:00
# 2024-07-01 00:00:00
# 2024-07-02 00:00:00
# 2024-07-03 00:00:00
# 2024-07-04 00:00:00
# 2024-07-05 00:00:00
# 2024-07-06 00:00:00
# 2024-07-07 00:00:00
# 2024-07-08 00:00:00
# 2024-07-09 00:00:00
# 2024-07-10 00:00:00
# 2024-07-11 00:00:00
# 2024-07-12 00:00:00
# 2024-07-13 00:00:00
# 2024-07-14 00:00:00
# 2024-07-15 00:00:00
# 2024-07-16 00:00:00
# 2024-07-17 00:00:00
# 2024-07-18 00:00:00
# 2024-07-19 00:00:00
# 2024-07-20 00:00:00
# 2024-07-21 00:00:00
# 2024-07-22 00:00:00
# 2024-07-23 00:00:00
# 2024-07-24 00:00:00
# 2024-07-25 00:00:00
# 2024-07-26 00:00:00
# 2024-07-27 00:00:00
# 2024-07-28 00:00:00
# 2024-07-29 00:00:00
# 2024-07-30 00:00:00
# 2024-07-31 00:00:00
# 2024-08-01 00:00:00
# 2024-08-02 00:00:00
# 2024-08-03 00:00:00
# 2024-08-04 00:00:00
# 2024-08-05 00:00:00
# 2024-08-06 00:00:00
# 2024-08-07 00:00:00
# 2024-08-08 00:00:00
# 2024-08-09 00:00:00
# 2024-08-10 00:00:00
# 2024-08-11 00:00:00
# 2024-08-12 00:00:00
# 2024-08-13 00:00:00
# 2024-08-14 00:00:00
# 2024-08-15 00:00:00
# 2024-08-16 00:00:00
# 2024-08-17 00:00:00
# 2024-08-18 00:00:00
# 2024-08-19 00:00:00
# 2024-08-20 00:00:00
# 2024-08-21 00:00:00
# 2024-08-22 00:00:00
# 2024-08-23 00:00:00
# 2024-08-24 00:00:00
# 2024-08-25 00:00:00
# 2024-08-26 00:00:00
# 2024-08-27 00:00:00
# 2024-08-28 00:00:00
# 2024-08-29 00:00:00
# 2024-08-30 00:00:00
# 2024-08-31 00:00:00
# 2024-09-01 00:00:00
# 2024-09-02 00:00:00
# 2024-09-03 00:00:00
# 2024-09-04 00:00:00
# 2024-09-05 00:00:00
# 2024-09-06 00:00:00
# 2024-09-07 00:00:00
# 2024-09-08 00:00:00
# 2024-09-09 00:00:00
# 2024-09-10 00:00:00
# 2024-09-11 00:00:00
# 2024-09-12 00:00:00
# 2024-09-13 00:00:00
# 2024-09-14 00:00:00
# 2024-09-15 00:00:00
# 2024-09-16 00:00:00
# 2024-09-17 00:00:00
# 2024-09-18 00:00:00
# 2024-09-19 00:00:00
# 2024-09-20 00:00:00
# 2024-09-21 00:00:00
# 2024-09-22 00:00:00
# 2024-09-23 00:00:00
# 2024-09-24 00:00:00
# 2024-09-25 00:00:00
# 2024-09-26 00:00:00
# 2024-09-27 00:00:00
# 2024-09-28 00:00:00
# 2024-09-29 00:00:00
# 2024-09-30 00:00:00
# 2024-10-01 00:00:00
# 2024-10-02 00:00:00
# 2024-10-03 00:00:00
# 2024-10-04 00:00:00
# 2024-10-05 00:00:00
# 2024-10-06 00:00:00
# 2024-10-07 00:00:00
# 2024-10-08 00:00:00
# 2024-10-09 00:00:00
# 2024-10-10 00:00:00
# 2024-10-11 00:00:00
# 2024-10-12 00:00:00
# 2024-10-13 00:00:00
# 2024-10-14 00:00:00
# 2024-10-15 00:00:00
# 2024-10-16 00:00:00
# 2024-10-17 00:00:00
# 2024-10-18 00:00:00
# 2024-10-19 00:00:00
# 2024-10-20 00:00:00
# 2024-10-21 00:00:00
# 2024-10-22 00:00:00
# 2024-10-23 00:00:00
# 2024-10-24 00:00:00
# 2024-10-25 00:00:00
# 2024-10-26 00:00:00
# 2024-10-27 00:00:00
# 2024-10-28 00:00:00
# 2024-10-29 00:00:00
# 2024-10-30 00:00:00
# 2024-10-31 00:00:00
# 2024-11-01 00:00:00
# 2024-11-02 00:00:00
# 2024-11-03 00:00:00
# 2024-11-04 00:00:00
# 2024-11-05 00:00:00
# 2024-11-06 00:00:00
# 2024-11-07 00:00:00
# 2024-11-08 00:00:00
# 2024-11-09 00:00:00
# 2024-11-10 00:00:00
# 2024-11-11 00:00:00
# 2024-11-12 00:00:00
# 2024-11-13 00:00:00
# 2024-11-14 00:00:00
# 2024-11-15 00:00:00
# 2024-11-16 00:00:00
# 2024-11-17 00:00:00
# 2024-11-18 00:00:00
# 2024-11-19 00:00:00
# 2024-11-20 00:00:00
# 2024-11-21 00:00:00
# 2024-11-22 00:00:00
# 2024-11-23 00:00:00
# 2024-11-24 00:00:00
# 2024-11-25 00:00:00
# 2024-11-26 00:00:00
# 2024-11-27 00:00:00
# 2024-11-28 00:00:00
# 2024-11-29 00:00:00
# 2024-11-30 00:00:00
# 2024-12-01 00:00:00
# 2024-12-02 00:00:00
# 2024-12-03 00:00:00
# 2024-12-04 00:00:00
# 2024-12-05 00:00:00
# 2024-12-06 00:00:00
# 2024-12-07 00:00:00
# 2024-12-08 00:00:00
# 2024-12-09 00:00:00
# 2024-12-10 00:00:00
# 2024-12-11 00:00:00
# 2024-12-12 00:00:00
# 2024-12-13 00:00:00
# 2024-12-14 00:00:00
# 2024-12-15 00:00:00
# 2024-12-16 00:00:00
# 2024-12-17 00:00:00
# 2024-12-18 00:00:00
# 2024-12-19 00:00:00
# 2024-12-20 00:00:00
# 2024-12-21 00:00:00
# 2024-12-22 00:00:00
# 2024-12-23 00:00:00
# 2024-12-24 00:00:00
# 2024-12-25 00:00:00
# 2024-12-26 00:00:00
# 2024-12-27 00:00:00
# 2024-12-28 00:00:00
# 2024-12-29 00:00:00
# 2024-12-30 00:00:00
# 2024-12-31 00:00:00

# %%
# Criando vetor de datas
import pandas as pd

# Criar um intervalo de datas
datas = pd.date_range(start='2024-01-01', end='2024-12-31', freq='D')

# Criar um DataFrame com as datas
df = pd.DataFrame({'Data': datas})

# Extrair os meses das datas e adicioná-los como uma nova coluna no DataFrame
df['Mes'] = df['Data'].dt.month
df['Dia'] = df['Data'].dt.dayofyear

# Mostrar o DataFrame resultante
print(df)
# Out:
#           Data  Mes  Dia
# 0   2024-01-01    1    1
# 1   2024-01-02    1    2
# 2   2024-01-03    1    3
# 3   2024-01-04    1    4
# 4   2024-01-05    1    5
# ..         ...  ...  ...
# 361 2024-12-27   12  362
# 362 2024-12-28   12  363
# 363 2024-12-29   12  364
# 364 2024-12-30   12  365
# 365 2024-12-31   12  366
#
# [366 rows x 3 columns]

# %%
#Ajustar meus numeros aleatórios com base no comprimento do vetor de datas

# Criando dataframe com datas e valores de atividade aleatória
import pandas as pd
#Extraindo o número de linhas/datas
n = df.shape[0]

# Criando atividade aleatória
atv = (atvMax - atvMin)*np.random.rand(n) + atvMin
df['atividade'] = atv*(60*60*24) #para que a atividade fique em ton/dia

print(df)
df.to_csv(r"C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski\tabelas\ativ.csv")


# Criando uma figura com os valores aleatórios
#fig, ax= plt.subplots()
#ax.plot(datas, atv)
# Out:
#           Data  Mes  Dia   atividade
# 0   2024-01-01    1    1  172.401638
# 1   2024-01-02    1    2  165.872746
# 2   2024-01-03    1    3  147.020285
# 3   2024-01-04    1    4  193.001316
# 4   2024-01-05    1    5  158.598625
# ..         ...  ...  ...         ...
# 361 2024-12-27   12  362  137.352331
# 362 2024-12-28   12  363  150.355066
# 363 2024-12-29   12  364  142.347964
# 364 2024-12-30   12  365  166.536248
# 365 2024-12-31   12  366  164.264748
#
# [366 rows x 4 columns]

# %%
meses = np.arange(1, 13)

# Criando componente sazonal
sazonalidade = (np.sin(2* np.pi * df['Dia'] / 365)) + 1

df['sazonalidade'] = sazonalidade 
plt.plot(sazonalidade)
df.to_csv(r"C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski\tabelas\ativ2.csv")
plt.plot(sazonalidade, color = 'black')

# %%
df['aleatorio'] =  (atvMax - atvMin)*np.random.rand(n) + atvMin

aleatorioSazonal = (df['atividade'] +  df['sazonalidade']*df['atividade'].mean())
df['aleatorioSazonal'] = aleatorioSazonal

fig,ax= plt.subplots(2)

ax[1].plot(df['Dia'], df['aleatorioSazonal'], color = 'black')
ax[0].plot(df['sazonalidade']*df['atividade'].mean(), color = 'black')
print(df['aleatorioSazonal'].mean())
# Out:
# 323.7044638569069

# %%
caminho = "C:\\Users\\anaju\\OneDrive\\Documentos\\GitHub\\Controle_AnaPietroski\\tabelas\\ativ2.csv"
df = pd.read_csv(caminho)

# Calcular a média da sazonalidade ao longo dos meses
media_sazonalidade = df.groupby('Mes')['sazonalidade'].mean()

# Plotar a sazonalidade média ao longo dos meses
plt.figure(figsize=(8, 6))
plt.plot(media_sazonalidade, marker='o', linestyle='-', color='black')
plt.xlabel('Mês')
plt.ylabel('Sazonalidade Média')
plt.xticks(range(1, 13), ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Suponha que você tenha os dados dos poluentes em um DataFrame chamado "df_poluentes"

# Lista de poluentes
poluentes = ['MP', 'SO2', 'CO']

# Para cada poluente, vamos criar os gráficos
for poluente in poluentes:
    # Criando os valores aleatórios e aleatórios sazonais
    df['aleatorio'] = (atvMax - atvMin) * np.random.rand(n) + atvMin
    aleatorioSazonal = (df['atividade'] + df['sazonalidade'] * df['atividade'].mean())
    df['aleatorioSazonal'] = aleatorioSazonal
    
    # Criando os subplots
    fig, ax = plt.subplots(2)
    
    # Plotando o gráfico dos valores aleatórios com sazonalidade
    ax[1].plot(df['Dia'], df['aleatorioSazonal'], color='black')
    ax[1].set_title('Valores Aleatórios Sazonais para {}'.format(poluente))
    ax[1].set_xlabel('Dia')
    ax[1].set_ylabel('Valor Aleatório Sazonal')
    ax[1].grid(True)
    
    # Plotando o gráfico da sazonalidade
    ax[0].plot(df['sazonalidade'] * df['atividade'].mean(), color='black')
    ax[0].set_title('Sazonalidade para {}'.format(poluente))
    ax[0].set_xlabel('Dia')
    ax[0].set_ylabel('Sazonalidade')
    ax[0].grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Coletando o caminho da pasta de que estou
cwd = os.getcwd()

# Pasta dos fatores de emissão
path = os.path.join(cwd, 'tabelas', 'FE')

# Indicando nome do arquivo
chapterNumer = 10
subChapter = 2
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'

# Abrindo arquivo utilizando o Pandas
fe = pd.read_csv(os.path.join(path, file))

# Definindo algumas variáveis
n = 365 #365 dias
atvMax = 0.00225 #atividade máxima de produção em ton/s
atvMin = 0.00150 #atividade mínima diária de produção em ton/s

dias = np.arange(1, n+1)  # Dias

# Lista de poluentes
poluentes = ['MP', 'SO2', 'CO']

# Para cada fonte de emissão, vamos criar os gráficos
for source in fe['Source'].unique():
    # Criando o gráfico
    fig, axs = plt.subplots(3, 1, figsize=(8, 10))
    
    # Para cada poluente, vamos gerar os valores aleatórios com sazonalidade senoidal
    for i, poluente in enumerate(poluentes):
        # Criando a sazonalidade senoidal
        sazonalidade = atvMax - (atvMax - atvMin) * np.sin(2 * np.pi * dias / n)
        
        # Multiplicando a sazonalidade pela atividade
        sazonalidade_atividade = sazonalidade * atv
        
        # Plotando o gráfico dos valores aleatórios com sazonalidade multiplicada pela atividade
        axs[i].plot(dias, sazonalidade_atividade, color='black')
        axs[i].set_title('Sazonalidade x Atividade para {} - {}'.format(source, poluente))
        axs[i].set_xlabel('Dia')
        axs[i].set_ylabel('Sazonalidade x Atividade (ton)')
        axs[i].grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Coletando o caminho da pasta de que estou
cwd = os.getcwd()

# Pasta dos fatores de emissão
path = os.path.join(cwd, 'tabelas', 'FE')

# Indicando nome do arquivo
chapterNumer = 10
subChapter = 2
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'

# Abrindo arquivo utilizando o Pandas
fe = pd.read_csv(os.path.join(path, file))

# Definindo algumas variáveis
n = 365 #365 dias
atvMax = 0.00225 #atividade máxima de produção em ton/s
atvMin = 0.00150 #atividade mínima diária de produção em ton/s

dias = np.arange(1, n+1)  # Dias

# Lista de poluentes
poluentes = ['MP', 'SO2', 'CO']

# Para cada fonte de emissão, vamos criar os gráficos
for source in fe['Source'].unique():
    # Criando o gráfico
    fig, axs = plt.subplots(3, 1, figsize=(8, 10))
    
    # Para cada poluente, vamos gerar os valores aleatórios com sazonalidade senoidal
    for i, poluente in enumerate(poluentes):
        # Criando a sazonalidade senoidal
        sazonalidade = atvMax - (atvMax - atvMin) * np.sin(2 * np.pi * dias / n)
        
        # Gerando valores aleatórios com sazonalidade senoidal
        aleatorioSazonal = (atvMax - atvMin) * np.random.rand(n) + atvMin + sazonalidade
        
        # Plotando o gráfico dos valores aleatórios com sazonalidade
        axs[i].plot(dias, aleatorioSazonal, color='black')
        axs[i].set_title('Valores Aleatórios Sazonais para {} - {}'.format(source, poluente))
        axs[i].set_xlabel('Dia')
        axs[i].set_ylabel('Segundo')
        axs[i].grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Coletando o caminho da pasta de que estou
cwd = os.getcwd()

# Pasta dos fatores de emissão
path = os.path.join(cwd, 'tabelas', 'FE')

# Indicando nome do arquivo
chapterNumer = 10
subChapter = 2
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'

# Abrindo arquivo utilizando o Pandas
fe = pd.read_csv(os.path.join(path, file))

# Definindo algumas variáveis
n = 365 # 365 dias
atvMax = 0.00225 # atividade máxima de produção em ton/s
atvMin = 0.00150 # atividade mínima diária de produção em ton/s

dias = np.arange(1, n+1)  # Dias

# Lista de poluentes
poluentes = ['MP', 'SO2', 'CO']

# Para cada fonte de emissão, vamos criar as tabelas de emissão
for source in fe['Source'].unique():
    # Criando um DataFrame para armazenar os resultados
    resultados = pd.DataFrame(columns=['Dia'] + poluentes)
    
    # Para cada dia, vamos calcular as emissões e armazenar no DataFrame
    for dia in dias:
        # Calculando a sazonalidade senoidal
        sazonalidade = atvMax - (atvMax - atvMin) * np.sin(2 * np.pi * dia / n)
        
        # Gerando valores aleatórios com sazonalidade senoidal para cada poluente
        aleatorioSazonal = (atvMax - atvMin) * np.random.rand(len(poluentes)) + atvMin + sazonalidade
        
        # Calculando as emissões em g/s para cada poluente
        emissao_gs = aleatorioSazonal * 1000 / (60 * 60)  # Convertendo de ton/s para g/s
        
        # Criando um dicionário com os dados do dia e as emissões de cada poluente
        dados_dia = {'Dia': dia}
        for i, poluente in enumerate(poluentes):
            dados_dia[poluente] = emissao_gs[i]
        
        # Adicionando os dados do dia ao DataFrame
        resultados.loc[len(resultados)] = dados_dia
    
    # Salvando a tabela de emissão em um arquivo CSV
    resultados.to_csv(os.path.join(path, 'emis_'+source+'.csv'), index=False)

    # Exibindo a tabela de emissão
    print(f'Tabela de emissão para {source}:')
    print(resultados)
# Out:
# Tabela de emissão para Tanque de dissolucao do smelt:
#      Dia        MP       SO2        CO
# 0      1  0.001109  0.001157  0.001062
# 1      2  0.001146  0.001083  0.001172
# 2      3  0.001075  0.001071  0.001157
# 3      4  0.001108  0.001152  0.001105
# 4      5  0.001198  0.001191  0.001184
# ..   ...       ...       ...       ...
# 360  361  0.001128  0.001072  0.001166
# 361  362  0.001217  0.001213  0.001062
# 362  363  0.001252  0.001052  0.001114
# 363  364  0.001063  0.001191  0.001201
# 364  365  0.001236  0.001173  0.001138
#
# [365 rows x 4 columns]
# Tabela de emissão para Forno de cal:
#      Dia        MP       SO2        CO
# 0      1  0.001164  0.001052  0.001047
# 1      2  0.001209  0.001175  0.001148
# 2      3  0.001130  0.001140  0.001034
# 3      4  0.001191  0.001124  0.001150
# 4      5  0.001218  0.001226  0.001157
# ..   ...       ...       ...       ...
# 360  361  0.001145  0.001155  0.001118
# 361  362  0.001225  0.001252  0.001159
# 362  363  0.001058  0.001107  0.001135
# 363  364  0.001168  0.001132  0.001076
# 364  365  0.001196  0.001079  0.001053
#
# [365 rows x 4 columns]
# Tabela de emissão para Condensador de terebitina:
#      Dia        MP       SO2        CO
# 0      1  0.001106  0.001245  0.001040
# 1      2  0.001108  0.001159  0.001100
# 2      3  0.001162  0.001062  0.001103
# 3      4  0.001141  0.001143  0.001184
# 4      5  0.001218  0.001061  0.001032
# ..   ...       ...       ...       ...
# 360  361  0.001132  0.001178  0.001210
# 361  362  0.001239  0.001166  0.001073
# 362  363  0.001246  0.001103  0.001063
# 363  364  0.001083  0.001145  0.001163
# 364  365  0.001157  0.001095  0.001156
#
# [365 rows x 4 columns]
# Tabela de emissão para Caldeira de forca (biomassa):
#      Dia        MP       SO2        CO
# 0      1  0.001235  0.001118  0.001183
# 1      2  0.001206  0.001044  0.001234
# 2      3  0.001199  0.001146  0.001053
# 3      4  0.001166  0.001080  0.001123
# 4      5  0.001188  0.001201  0.001032
# ..   ...       ...       ...       ...
# 360  361  0.001180  0.001096  0.001172
# 361  362  0.001241  0.001113  0.001187
# 362  363  0.001155  0.001078  0.001067
# 363  364  0.001164  0.001130  0.001098
# 364  365  0.001144  0.001232  0.001093
#
# [365 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Definindo os fatores de emissão por processo (fonte) e poluente
path = os.path.join(cwd, 'tabelas', 'FE')  # Substitua pelo caminho correto do seu arquivo

# Definindo a taxa de atividade em toneladas/ano
atv = 70000

# Calculando as emissões para cada poluente e fonte
emissoes_por_processo = fe.drop(columns='Source') * atv

# Calculando a soma das emissões considerando todos os processos
soma_emissoes = emissoes_por_processo.sum().sum()  # Soma de todas as células do DataFrame

# Calculando a emissão média, mínima e máxima
emissao_media = emissoes_por_processo.mean().mean()
emissao_minima = emissoes_por_processo.min().min()
emissao_maxima = emissoes_por_processo.max().max()

# Exibindo os resultados
print("Soma das emissões de todos os processos:", soma_emissoes, "g/s")
print("Emissão média:", emissao_media, "g/s")
print("Emissão mínima:", emissao_minima, "g/s")
print("Emissão máxima:", emissao_maxima, "g/s")

# Plotando os gráficos para cada poluente
for poluente in emissoes_por_processo.columns:
    # Obtendo os dados de emissão para o poluente atual
    dados_emissao = emissoes_por_processo[poluente]
    
    # Plotando o gráfico de barras
    plt.figure(figsize=(10, 6))
    plt.bar(dados_emissao.index, dados_emissao.values, color='skyblue')
    plt.title(f'Emissão de {poluente} por fonte', fontsize=14)
    plt.xlabel('Fonte', fontsize=12)
    plt.ylabel('Emissão (g/s)', fontsize=12)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
# Out:
# Soma das emissões de todos os processos: 2871750.0 g/s
# Emissão média: 340277.7777777778 g/s
# Emissão mínima: 3500.0 g/s
# Emissão máxima: 1960000.0 g/s

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Definindo os fatores de emissão por processo (fonte) e poluente
path = os.path.join(cwd, 'tabelas', 'FE')  # Substitua pelo caminho correto do seu arquivo

# Definindo a taxa de atividade em toneladas/ano
atv = 70000

# Calculando as emissões para cada poluente e fonte
emissoes_por_processo = fe.drop(columns='Source') * atv

# Separando os poluentes de Material Particulado (MP)
mp_poluentes = ['MP10', 'MP2.5']
emissoes_mp = emissoes_por_processo[mp_poluentes]

# Calculando a soma das emissões considerando todos os processos para MP
soma_emissoes_mp = emissoes_mp.sum().sum()

# Exibindo a soma das emissões para MP
print("Soma das emissões de MP:", soma_emissoes_mp, "g/s")

# Plotando o gráfico para MP
plt.figure(figsize=(10, 6))
for poluente in emissoes_mp.columns:
    # Obtendo os dados de emissão para o poluente atual
    dados_emissao = emissoes_mp[poluente]
    fontes = dados_emissao.index
    
    # Plotando o gráfico de linhas
    plt.plot(fontes, dados_emissao.values, marker='o', label=poluente)

plt.title('Emissão por fonte para Material Particulado', fontsize=14)
plt.xlabel('Fonte', fontsize=12)
plt.ylabel('Emissão (g/s)', fontsize=12)
plt.xticks(fontsize=10, rotation=45, ha='right')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 16
#      14 # Separando os poluentes de Material Particulado (MP)
#      15 mp_poluentes = ['MP10', 'MP2.5']
# ---> 16 emissoes_mp = emissoes_por_processo[mp_poluentes]
#      18 # Calculando a soma das emissões considerando todos os processos para MP
#      19 soma_emissoes_mp = emissoes_mp.sum().sum()
#
# File ~\OneDrive\Documentos\GitHub\Controle_AnaPietroski\venv\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~\OneDrive\Documentos\GitHub\Controle_AnaPietroski\venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\OneDrive\Documentos\GitHub\Controle_AnaPietroski\venv\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['MP10', 'MP2.5'], dtype='object')] are in the [columns]"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Coletando o caminho da pasta de que estou
cwd = os.getcwd()

# Pasta dos fatores de emissão
path = os.path.join(cwd, 'tabelas', 'FE')

# Indicando nome do arquivo
chapterNumer = 10
subChapter = 2
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'

# Abrindo arquivo utilizando o Pandas
fe = pd.read_csv(os.path.join(path, file))

# Definindo algumas variáveis para simular os dados
n = 365 #hora no ano
atvMax = 0.00225
atvMin = 0.00150

# Lista de poluentes
poluentes = ['MP', 'SO2', 'CO']

# Para cada fonte de emissão, vamos criar os gráficos
for source in fe['Source'].unique():
    # Criando o gráfico
    fig, ax = plt.subplots()
    
    # Para cada poluente, vamos gerar os valores aleatórios e aleatórios sazonais
    for poluente in poluentes:
        aleatorio = (atvMax - atvMin) * np.random.rand(n) + atvMin
        sazonalidade = fe.loc[(fe['Source'] == source), poluente].values[0]
        aleatorioSazonal = aleatorio + sazonalidade
        
        # Plotando os valores aleatórios com sazonalidade
        ax.plot(range(n), aleatorioSazonal, label=poluente)

    ax.set_title('Valores Aleatórios Sazonais para {}'.format(source))
    ax.set_xlabel('Dia')
    ax.set_ylabel('Valor Aleatório Sazonal')
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Coletando o caminho da pasta de que estou
cwd = os.getcwd()

# Pasta dos fatores de emissão
path = os.path.join(cwd, 'tabelas', 'FE')

# Indicando nome do arquivo
chapterNumer = 10
subChapter = 2
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'

# Abrindo arquivo utilizando o Pandas
fe = pd.read_csv(os.path.join(path, file))

# Lista de poluentes
poluentes = fe['Source'].unique()

# Definindo algumas variáveis para simular os dados
n = 365  # dias
atvMax = 0.0025  # Atividade máxima
atvMin = 0.0015  # Atividade mínima

# Para cada poluente, vamos criar os gráficos
for poluente in poluentes:
    # Criando os valores aleatórios e aleatórios sazonais
    aleatorio = (atvMax - atvMin) * np.random.rand(n) + atvMin
    sazonalidade = fe.loc[fe['Source'] == poluente, 'MP'].values[0]  # Aqui ajustamos para pegar o valor do poluente 'MP'
    aleatorioSazonal = aleatorio + sazonalidade
    
    # Criando os subplots
    fig, ax = plt.subplots(2)
    
    # Plotando o gráfico dos valores aleatórios com sazonalidade
    ax[1].plot(range(n), aleatorioSazonal, color='black')
    ax[1].set_title('Valores Aleatórios Sazonais para {}'.format(poluente))
    ax[1].set_xlabel('Dia')
    ax[1].set_ylabel('Valor Aleatório Sazonal')
    ax[1].grid(True)
    
    # Plotando o gráfico da sazonalidade
    ax[0].plot(range(n), [sazonalidade]*n, color='black')
    ax[0].set_title('Sazonalidade para {}'.format(poluente))
    ax[0].set_xlabel('Dia')
    ax[0].set_ylabel('Sazonalidade')
    ax[0].grid(True)
    
    plt.tight_layout()
    plt.show()
