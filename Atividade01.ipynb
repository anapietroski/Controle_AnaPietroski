# %%
# Utilizando Pandas para abrir a planilha
import pandas as pd
import os

# Coletando o caminho da pasta de que estou
cwd = os.getcwd()
print(cwd)

# Pasta dos fatores de emissão
path = cwd+'\\tabelas\\FE'
print(path)

# Indicando nome do arquivo
chapterNumer = 10
subChapter = 2
file = 'chp_'+str(chapterNumer)+'_'+str(subChapter)+'.csv'
print(file)

# Abrindo arquivo utilizando o Pandas
fe = pd.read_csv(path + '\\'+file)
print(fe)
# Out:
# C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski
# C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski\tabelas\FE
# chp_10_2.csv
#                           Source    MP    SO2    CO
# 0  Tanque de dissolucao do smelt   3.5  0.100   NaN
# 1                   Forno de cal  28.0  0.150  0.05
# 2      Condensador de terebitina   NaN    NaN   NaN
# 3   Caldeira de forca (biomassa)   3.6  0.225  5.40

# %%
#Estimativa das emissões do empreendimento (e plotagem)

import matplotlib.pyplot as plt

atv = 70000 #Considerando taxa de atividade em toneladas/ano
emis = fe['MP']*atv

#Somando dataframe
print(emis.sum())

#Criando a figura com Matplotlib
#Subplots com número de linhas igual ao numero de poluentes
fig, ax = plt.subplots(len(fe.columns) - 1, 1, sharex = True, figsize=(9, 15)) #sharex significa compartilhar o eixo x

#Look para preencher o subplot com os gráficos de barra
for ii in range(1, len(fe.columns)): #a primeira coluna é a identificação da fonte
    ax[ii-1].bar(fe['Source'], fe.iloc[:,ii], color = 'black')
    ax[ii-1].set_xlabel('Processo', fontsize=8) #coloca o eixo x
    ax[ii-1].set_ylabel(fe.columns[ii]+'\n(kg/ton)', fontsize=8)

    ax[ii-1].tick_params(axis='x', labelsize=8)
    ax[ii-1].tick_params(axis='y', labelsize=8)

    ax[ii-1].set_xticks(fe['Source'].index)
    ax[ii-1].set_xticklabels(fe['Source'], rotation=45, ha='right', fontsize=8)

# Adicionando valores acima das barras
    for bar, value in zip(ax[ii - 1].patches, fe.iloc[:, ii]):
        ax[ii - 1].annotate('{:.2f}'.format(value), xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
                            xytext=(0, 3),  # 3 points vertical offset
                            textcoords="offset points",
                            ha='center', va='bottom', fontsize=8)

#O gráfico a seguir representa o fator de emissão para cada processo, basicamente pegou os dados da tabela e apresentou em figura
# Out:
# 2457000.0

# %%
df = pd.read_csv(path + '\\'+file)

# Encontrando a emissão dos poluentes para cada processo 
poluentes = ['MP', 'SO2', 'CO']
df[poluentes] *= atv

print(df)
# Out:
#                           Source         MP      SO2        CO
# 0  Tanque de dissolucao do smelt   245000.0   7000.0       NaN
# 1                   Forno de cal  1960000.0  10500.0    3500.0
# 2      Condensador de terebitina        NaN      NaN       NaN
# 3   Caldeira de forca (biomassa)   252000.0  15750.0  378000.0

# %%
# Criando vetor de valores aleatórios. Será criado em ton/dia para melhor cálculo das etapas seguintes.
import numpy as np
atvMax = 0.00225 #atividade máxima de produção em ton/dia
atvMin = 0.00150 #atividade mínima diária de produção em ton/dia
n = 1000 #1000 valores aleatórios
atv = (atvMax - atvMin)*np.random.rand(n) + atvMin

#Criando uma figura com os valores aleatórios
fig, ax = plt.subplots()

plt.xlabel('Valores aleatórios')
plt.ylabel('Atividade (ton/s)')
    
ax.plot(atv)

# %%
# 2024-10-26 00:00:00
# 2024-10-27 00:00:00
# 2024-10-28 00:00:00
# 2024-10-29 00:00:00
# 2024-10-30 00:00:00
# 2024-10-31 00:00:00
# 2024-11-01 00:00:00
# 2024-11-02 00:00:00
# 2024-11-03 00:00:00
# 2024-11-04 00:00:00
# 2024-11-05 00:00:00
# 2024-11-06 00:00:00
# 2024-11-07 00:00:00
# 2024-11-08 00:00:00
# 2024-11-09 00:00:00
# 2024-11-10 00:00:00
# 2024-11-11 00:00:00
# 2024-11-12 00:00:00
# 2024-11-13 00:00:00
# 2024-11-14 00:00:00
# 2024-11-15 00:00:00
# 2024-11-16 00:00:00
# 2024-11-17 00:00:00
# 2024-11-18 00:00:00
# 2024-11-19 00:00:00
# 2024-11-20 00:00:00
# 2024-11-21 00:00:00
# 2024-11-22 00:00:00
# 2024-11-23 00:00:00
# 2024-11-24 00:00:00
# 2024-11-25 00:00:00
# 2024-11-26 00:00:00
# 2024-11-27 00:00:00
# 2024-11-28 00:00:00
# 2024-11-29 00:00:00
# 2024-11-30 00:00:00
# 2024-12-01 00:00:00
# 2024-12-02 00:00:00
# 2024-12-03 00:00:00
# 2024-12-04 00:00:00
# 2024-12-05 00:00:00
# 2024-12-06 00:00:00
# 2024-12-07 00:00:00
# 2024-12-08 00:00:00
# 2024-12-09 00:00:00
# 2024-12-10 00:00:00
# 2024-12-11 00:00:00
# 2024-12-12 00:00:00
# 2024-12-13 00:00:00
# 2024-12-14 00:00:00
# 2024-12-15 00:00:00
# 2024-12-16 00:00:00
# 2024-12-17 00:00:00
# 2024-12-18 00:00:00
# 2024-12-19 00:00:00
# 2024-12-20 00:00:00
# 2024-12-21 00:00:00
# 2024-12-22 00:00:00
# 2024-12-23 00:00:00
# 2024-12-24 00:00:00
# 2024-12-25 00:00:00
# 2024-12-26 00:00:00
# 2024-12-27 00:00:00
# 2024-12-28 00:00:00
# 2024-12-29 00:00:00
# 2024-12-30 00:00:00
# 2024-12-31 00:00:00

# %%
# Criando vetor de datas
import pandas as pd

# Criar um intervalo de datas
datas = pd.date_range(start='2024-01-01', end='2024-12-31', freq='D')

# Criar um DataFrame com as datas
df = pd.DataFrame({'Data': datas})

# Extrair os meses das datas e adicioná-los como uma nova coluna no DataFrame
df['Mes'] = df['Data'].dt.month

# Mostrar o DataFrame resultante
print(df)
# Out:
#           Data  Mes
# 0   2024-01-01    1
# 1   2024-01-02    1
# 2   2024-01-03    1
# 3   2024-01-04    1
# 4   2024-01-05    1
# ..         ...  ...
# 361 2024-12-27   12
# 362 2024-12-28   12
# 363 2024-12-29   12
# 364 2024-12-30   12
# 365 2024-12-31   12
#
# [366 rows x 2 columns]

# %%
#Ajustar meus numeros aleatórios com base no comprimento do vetor de datas

# Criando dataframe com datas e valores de atividade aleatória
import pandas as pd
#Extraindo o número de linhas/datas
n = df.shape[0]

# Criando atividade aleatória
atv = (atvMax - atvMin)*np.random.rand(n) + atvMin
df['atividade'] = atv*(60*60*24) #para que a atividade fique em ton/dia

print(df)
df.to_csv(r"C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski\tabelas\ativ.csv")


# Criando uma figura com os valores aleatórios
#fig, ax= plt.subplots()
#ax.plot(datas, atv)
# Out:
#           Data  Mes   atividade
# 0   2024-01-01    1  151.215916
# 1   2024-01-02    1  173.412333
# 2   2024-01-03    1  150.134879
# 3   2024-01-04    1  160.044723
# 4   2024-01-05    1  133.796467
# ..         ...  ...         ...
# 361 2024-12-27   12  164.532209
# 362 2024-12-28   12  185.035851
# 363 2024-12-29   12  160.484551
# 364 2024-12-30   12  171.207645
# 365 2024-12-31   12  174.913505
#
# [366 rows x 3 columns]

# %%
meses = np.arange(1, 13)

# Criando componente sazonal
sazonalidade = np.sin((meses - 8) * (2 * np.pi / 12))+1

# Criando um DataFrame para visualização
df = pd.DataFrame({'Mes': meses, 'Sazonalidade': sazonalidade})
df.to_csv(r"C:\Users\anaju\OneDrive\Documentos\GitHub\Controle_AnaPietroski\tabelas\ativ2.csv")
plt.plot(sazonalidade)

# %%
caminho = "C:\\Users\\anaju\\OneDrive\\Documentos\\GitHub\\Controle_AnaPietroski\\tabelas\\ativ.csv"
df = pd.read_csv(caminho)

# Calcular a média da produção por mês
df['Data'] = pd.to_datetime(df['Data'])
df['Mes'] = df['Data'].dt.month
media_mensal = df.groupby('Mes')['atividade'].mean()

# Normalizar a média mensal entre a produção máxima e mínima
producao_maxima = 192
producao_minima = 128
media_normalizada = (media_mensal - media_mensal.min()) / (media_mensal.max() - media_mensal.min()) \
                    * (producao_maxima - producao_minima) + producao_minima

# Ajuste sazonal
meses = media_normalizada.index
atividades_normalizadas = media_normalizada.values

# Ajuste sazonal usando uma função seno
sazonalidade = np.sin((meses - 8) * (2 * np.pi / 12))  

# Ajustando a produção considerando a sazonalidade e a escala
escala = (producao_maxima - producao_minima) / 2
producao_ajustada = producao_minima + escala * (sazonalidade + 1)

# Plotar o gráfico
plt.figure(figsize=(10, 6))
plt.plot(meses, producao_ajustada, marker='o', linestyle='-')
plt.xlabel('Mês')
plt.ylabel('Produção ajustada (ton/dia)')
plt.xticks(range(1, 13), ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
plt.ylim(100, 200)  # Definindo o limite do eixo y
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Valores aleatórios com sazonalidade
#df['aleatorioSazonal'] = df['atividade'] * df['sazonalidade'] 

# Definindo os parâmetros
atvMax = 0.00225 # Atividade máxima de produção em ton/dia
atvMin = 0.00150 # Atividade mínima diária de produção em ton/dia
n = 365 # Número de dias no ano

# Criando um vetor de dias do ano
dias_do_ano = np.arange(1, n+1)

# Calculando a sazonalidade usando uma função seno
sazonalidade = np.sin((dias_do_ano - 1) * (2 * np.pi / n))+1

# Calculando os valores aleatórios com sazonalidade
aleatorio_sazonal = (atvMax - atvMin) * np.random.rand(n) + atvMin
aleatorio_sazonal *= sazonalidade * aleatorio_sazonal.mean() * 0.415

# Plotando os gráficos
fig, ax = plt.subplots(2, 1, figsize=(10, 8))

# Gráfico da sazonalidade ao longo do ano
ax[0].plot(dias_do_ano, sazonalidade, color='blue')
ax[0].set_title('Sazonalidade ao Longo do Ano')
ax[0].set_xlabel('Dia do Ano')
ax[0].set_ylabel('Sazonalidade')
ax[0].grid(True)

# Gráfico dos valores aleatórios com sazonalidade ao longo do ano
ax[1].plot(dias_do_ano, aleatorio_sazonal, color='green')
ax[1].set_title('Valores Aleatórios com Sazonalidade ao Longo do Ano')
ax[1].set_xlabel('Dia do Ano')
ax[1].set_ylabel('Valores Aleatórios com Sazonalidade')
ax[1].grid(True)

plt.tight_layout()
plt.show()
